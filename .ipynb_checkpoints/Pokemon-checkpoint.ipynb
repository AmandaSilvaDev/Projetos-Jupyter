# %%
import pandas as pd

# %%
#importando tabela
df = pd.read_html('https://gist.github.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6')[0]

# %%
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0           NaN    1              Bulbasaur    Grass  Poison    318  45
# 1           NaN    2                Ivysaur    Grass  Poison    405  60
# 2           NaN    3               Venusaur    Grass  Poison    525  80
# 3           NaN    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4           NaN    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         NaN  719                Diancie     Rock   Fairy    600  50
# 796         NaN  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         NaN  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         NaN  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         NaN  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        49       49       65       65     45           1      False
# 1        62       63       80       80     60           1      False
# 2        82       83      100      100     80           1      False
# 3       100      123      122      120     80           1      False
# 4        52       43       60       50     65           1      False
# ..      ...      ...      ...      ...    ...         ...        ...
# 795     100      150      100      150     50           6       True
# 796     160      110      160      110    110           6       True
# 797     110       60      150      130     70           6       True
# 798     160       60      170      130     80           6       True
# 799     110      120      130       90     70           6       True
#
# [800 rows x 14 columns]

# %%
#selecionar uma coluna do DataFrame
coluna = df['Name']

#selecionar varias colunas
colunas = df[['Name','Type 1']]

#selecionar linhas do dataframe com vase em condições
linhas = df[df['Attack'] > 100]

# %%
linhas
# Out:
#      Unnamed: 0    #                       Name   Type 1  Type 2  Total   HP  \
# 7           NaN    6  CharizardMega Charizard X     Fire  Dragon    634   78
# 8           NaN    6  CharizardMega Charizard Y     Fire  Flying    634   78
# 12          NaN    9    BlastoiseMega Blastoise    Water     NaN    630   79
# 19          NaN   15      BeedrillMega Beedrill      Bug  Poison    495   65
# 39          NaN   34                   Nidoking   Poison  Ground    505   81
# ..          ...  ...                        ...      ...     ...    ...  ...
# 793         NaN  717                    Yveltal     Dark  Flying    680  126
# 796         NaN  719        DiancieMega Diancie     Rock   Fairy    700   50
# 797         NaN  720        HoopaHoopa Confined  Psychic   Ghost    600   80
# 798         NaN  720         HoopaHoopa Unbound  Psychic    Dark    680   80
# 799         NaN  721                  Volcanion     Fire   Water    600   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7       130      111      130       85    100           1      False
# 8       104       78      159      115    100           1      False
# 12      103      120      135      115     78           1      False
# 19      150       40       15       80    145           1      False
# 39      102       77       85       75     85           1      False
# ..      ...      ...      ...      ...    ...         ...        ...
# 793     131       95      131       98     99           6       True
# 796     160      110      160      110    110           6       True
# 797     110       60      150      130     70           6       True
# 798     160       60      170      130     80           6       True
# 799     110      120      130       90     70           6       True
#
# [170 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   #           800 non-null    int64
#  2   Name        800 non-null    object
#  3   Type 1      800 non-null    object
#  4   Type 2      414 non-null    object
#  5   Total       800 non-null    int64
#  6   HP          800 non-null    int64
#  7   Attack      800 non-null    int64
#  8   Defense     800 non-null    int64
#  9   Sp. Atk     800 non-null    int64
#  10  Sp. Def     800 non-null    int64
#  11  Speed       800 non-null    int64
#  12  Generation  800 non-null    int64
#  13  Legendary   800 non-null    bool
# dtypes: bool(1), float64(1), int64(9), object(3)
# memory usage: 82.2+ KB

# %%
df[(df['Attack'] >= 80) & (df['Defense'] >= 150)]
# Out:
#      Unnamed: 0    #                     Name  Type 1   Type 2  Total   HP  \
# 98          NaN   91                 Cloyster   Water      Ice    525   50
# 223         NaN  208                  Steelix   Steel   Ground    510   75
# 224         NaN  208      SteelixMega Steelix   Steel   Ground    610   75
# 268         NaN  248  TyranitarMega Tyranitar    Rock     Dark    700  100
# 332         NaN  306                   Aggron   Steel     Rock    530   70
# 333         NaN  306        AggronMega Aggron   Steel      NaN    630   70
# 413         NaN  376  MetagrossMega Metagross   Steel  Psychic    700   80
# 414         NaN  377                 Regirock    Rock      NaN    580   80
# 424         NaN  383    GroudonPrimal Groudon  Ground     Fire    770  100
# 749         NaN  680                 Doublade   Steel    Ghost    448   59
# 789         NaN  713                  Avalugg     Ice      NaN    514   95
# 795         NaN  719                  Diancie    Rock    Fairy    600   50
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 98       95      180       85       45     70           1      False
# 223      85      200       55       65     30           2      False
# 224     125      230       55       95     30           2      False
# 268     164      150       95      120     71           2      False
# 332     110      180       60       60     50           3      False
# 333     140      230       60       80     50           3      False
# 413     145      150      105      110    110           3      False
# 414     100      200       50      100     50           3       True
# 424     180      160      150       90     90           3       True
# 749     110      150       45       49     35           6      False
# 789     117      184       44       46     28           6      False
# 795     100      150      100      150     50           6       True

# %%
#operação 
df['Indice de força'] = df['Attack'] + df['Defense']+ df['Speed']

# %%
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0           NaN    1              Bulbasaur    Grass  Poison    318  45
# 1           NaN    2                Ivysaur    Grass  Poison    405  60
# 2           NaN    3               Venusaur    Grass  Poison    525  80
# 3           NaN    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4           NaN    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         NaN  719                Diancie     Rock   Fairy    600  50
# 796         NaN  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         NaN  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         NaN  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         NaN  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 0        49       49       65       65     45           1      False
# 1        62       63       80       80     60           1      False
# 2        82       83      100      100     80           1      False
# 3       100      123      122      120     80           1      False
# 4        52       43       60       50     65           1      False
# ..      ...      ...      ...      ...    ...         ...        ...
# 795     100      150      100      150     50           6       True
# 796     160      110      160      110    110           6       True
# 797     110       60      150      130     70           6       True
# 798     160       60      170      130     80           6       True
# 799     110      120      130       90     70           6       True
#
#      Indice de força
# 0                143
# 1                185
# 2                245
# 3                303
# 4                160
# ..               ...
# 795              300
# 796              380
# 797              240
# 798              300
# 799              300
#
# [800 rows x 15 columns]

# %%
df.sort_values(by = "Indice de força", ascending = False)
# Out:
#      Unnamed: 0    #                     Name   Type 1    Type 2  Total   HP  \
# 424         NaN  383    GroudonPrimal Groudon   Ground      Fire    770  100
# 333         NaN  306        AggronMega Aggron    Steel       NaN    630   70
# 163         NaN  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106
# 413         NaN  376  MetagrossMega Metagross    Steel   Psychic    700   80
# 409         NaN  373  SalamenceMega Salamence   Dragon    Flying    700   95
# ..          ...  ...                      ...      ...       ...    ...  ...
# 261         NaN  242                  Blissey   Normal       NaN    540  255
# 187         NaN  173                   Cleffa    Fairy       NaN    218   50
# 188         NaN  174                Igglybuff   Normal     Fairy    210   90
# 121         NaN  113                  Chansey   Normal       NaN    450  250
# 488         NaN  440                  Happiny   Normal       NaN    220  100
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 424     180      160      150       90     90           3       True
# 333     140      230       60       80     50           3      False
# 163     190      100      154      100    130           1       True
# 413     145      150      105      110    110           3      False
# 409     145      130      120       90    120           3      False
# ..      ...      ...      ...      ...    ...         ...        ...
# 261      10       10       75      135     55           2      False
# 187      25       28       45       55     15           2      False
# 188      30       15       40       20     15           2      False
# 121       5        5       35      105     50           1      False
# 488       5        5       15       65     30           4      False
#
#      Indice de força
# 424              430
# 333              420
# 163              420
# 413              405
# 409              395
# ..               ...
# 261               75
# 187               68
# 188               60
# 121               60
# 488               40
#
# [800 rows x 15 columns]

# %%
#excluir coluna
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
import matplotlib.pyplot as plt

# %%
ListaForca = df[['Name','Attack']]

# %%
ListaForca
# Out:
#                       Name  Attack
# 0                Bulbasaur      49
# 1                  Ivysaur      62
# 2                 Venusaur      82
# 3    VenusaurMega Venusaur     100
# 4               Charmander      52
# ..                     ...     ...
# 795                Diancie     100
# 796    DiancieMega Diancie     160
# 797    HoopaHoopa Confined     110
# 798     HoopaHoopa Unbound     160
# 799              Volcanion     110
#
# [800 rows x 2 columns]

# %%
plt.bar(df['Name'], df['Attack'])
plt.show()

# %%
ListaForca.head()
# Out:
#                     Name  Attack
# 0              Bulbasaur      49
# 1                Ivysaur      62
# 2               Venusaur      82
# 3  VenusaurMega Venusaur     100
# 4             Charmander      52

# %%
df.drop(columns = ['#'], inplace = True)

# %%
df.groupby(['Type 1']).mean()
# Out:
# C:\Users\Amanda\AppData\Local\Temp\ipykernel_10980\2210688449.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Type 1']).mean()
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       378.927536  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  443.409091  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     413.176471  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     421.142857  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# Ice       433.458333  72.000000   72.750000   71.416667  77.541667  76.291667
# Normal    401.683673  77.275510   73.469388   59.846939  55.816327  63.724490
# Poison    399.142857  67.250000   74.678571   68.821429  60.428571  64.392857
# Psychic   475.947368  70.631579   71.456140   67.684211  98.403509  86.280702
# Rock      453.750000  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     487.703704  65.222222   92.703704  126.370370  67.518519  80.629630
# Water     430.455357  72.062500   74.151786   72.946429  74.812500  70.517857
#
#                Speed  Generation  Legendary  Indice de força
# Type 1
# Bug        61.681159    3.217391   0.000000       203.376812
# Dark       76.161290    4.032258   0.064516       234.774194
# Dragon     83.031250    3.875000   0.375000       281.531250
# Electric   84.500000    3.272727   0.090909       219.886364
# Fairy      48.588235    4.117647   0.058824       175.823529
# Fighting   66.074074    3.370370   0.000000       228.777778
# Fire       74.442308    3.211538   0.096154       226.980769
# Flying    102.500000    5.500000   0.500000       247.500000
# Ghost      64.343750    4.187500   0.062500       219.312500
# Grass      61.928571    3.357143   0.042857       205.942857
# Ground     63.906250    3.156250   0.125000       244.500000
# Ice        63.458333    3.541667   0.083333       207.625000
# Normal     71.551020    3.051020   0.020408       204.867347
# Poison     63.571429    2.535714   0.000000       207.071429
# Psychic    81.491228    3.385965   0.245614       220.631579
# Rock       55.909091    3.454545   0.090909       249.568182
# Steel      55.259259    3.851852   0.148148       274.333333
# Water      65.964286    2.857143   0.035714       213.062500

# %%
df.groupby(['Type 1']).plot()
plt.show()
